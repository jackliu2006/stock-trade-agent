# %%
# %pip install langchain_core langchain_google_genai

# %%
import os

from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

client = ChatGoogleGenerativeAI(
    model="gemini-3.1-pro-preview",  # see table above to set the desired model id
    client_options={"api_endpoint": "https://genai-nexus.int.api.corpinter.net"},
    google_api_key=dbutils.secrets.get(scope="llm-test", key="nexus-api-key"),
    transport="rest",       # otherwise will use gRPC which is not supported by Nexus
)

response = client.generate([
    [HumanMessage(content="capital of china?")]
])
print(response)
